# %%
import numpy as np

X = np.array([1,2,3,4], dtype=np.float32)
Y = np.array([2,4,6,8   ], dtype=np.float32)

weights = 0.0

# Model prediction
def forward(x):
    return weights * x

# loss
def loss(y, y_predicted):
    return ((y_predicted -y )**2).mean()

# gradient

#MSE = 1/N * (w*x - y)**2

#dl/dw = 1/N 2x (w*x - y)
def gradient(x,y,y_predicted):
    return np.dot(2*x, y_predicted - y).mean()

print(f'Prediction before training: f(5) = {forward(5):.3f}')

#Training
learning_rate = 0.01
n_iters = 100

for epoch in range(n_iters):
    # prediction = forward pass
    y_pred = forward(X)

    # loss
    l = loss(Y, y_pred)

    # gradients
    dw = gradient(X, Y, y_pred)

    # update weights
    weights -= learning_rate * dw

    if epoch % 1 == 0:
        print(f'epoch {epoch + 1}: weights = {weights:.3f}, loss = {l:.8f}')

print(f'Prediction after training: f(5) = {forward(5):.3f}')
# Out:
# Prediction before training: f(5) = 0.000
# epoch 1: weights = 1.200, loss = 30.00000000
# epoch 2: weights = 1.680, loss = 4.79999924
# epoch 3: weights = 1.872, loss = 0.76800019
# epoch 4: weights = 1.949, loss = 0.12288000
# epoch 5: weights = 1.980, loss = 0.01966083
# epoch 6: weights = 1.992, loss = 0.00314570
# epoch 7: weights = 1.997, loss = 0.00050332
# epoch 8: weights = 1.999, loss = 0.00008053
# epoch 9: weights = 1.999, loss = 0.00001288
# epoch 10: weights = 2.000, loss = 0.00000206
# epoch 11: weights = 2.000, loss = 0.00000033
# epoch 12: weights = 2.000, loss = 0.00000005
# epoch 13: weights = 2.000, loss = 0.00000001
# epoch 14: weights = 2.000, loss = 0.00000000
# epoch 15: weights = 2.000, loss = 0.00000000
# epoch 16: weights = 2.000, loss = 0.00000000
# epoch 17: weights = 2.000, loss = 0.00000000
# epoch 18: weights = 2.000, loss = 0.00000000
# epoch 19: weights = 2.000, loss = 0.00000000
# epoch 20: weights = 2.000, loss = 0.00000000
# epoch 21: weights = 2.000, loss = 0.00000000
# epoch 22: weights = 2.000, loss = 0.00000000
# epoch 23: weights = 2.000, loss = 0.00000000
# epoch 24: weights = 2.000, loss = 0.00000000
# epoch 25: weights = 2.000, loss = 0.00000000
# epoch 26: weights = 2.000, loss = 0.00000000
# epoch 27: weights = 2.000, loss = 0.00000000
# epoch 28: weights = 2.000, loss = 0.00000000
# epoch 29: weights = 2.000, loss = 0.00000000
# epoch 30: weights = 2.000, loss = 0.00000000
# epoch 31: weights = 2.000, loss = 0.00000000
# epoch 32: weights = 2.000, loss = 0.00000000
# epoch 33: weights = 2.000, loss = 0.00000000
# epoch 34: weights = 2.000, loss = 0.00000000
# epoch 35: weights = 2.000, loss = 0.00000000
# epoch 36: weights = 2.000, loss = 0.00000000
# epoch 37: weights = 2.000, loss = 0.00000000
# epoch 38: weights = 2.000, loss = 0.00000000
# epoch 39: weights = 2.000, loss = 0.00000000
# epoch 40: weights = 2.000, loss = 0.00000000
# epoch 41: weights = 2.000, loss = 0.00000000
# epoch 42: weights = 2.000, loss = 0.00000000
# epoch 43: weights = 2.000, loss = 0.00000000
# epoch 44: weights = 2.000, loss = 0.00000000
# epoch 45: weights = 2.000, loss = 0.00000000
# epoch 46: weights = 2.000, loss = 0.00000000
# epoch 47: weights = 2.000, loss = 0.00000000
# epoch 48: weights = 2.000, loss = 0.00000000
# epoch 49: weights = 2.000, loss = 0.00000000
# epoch 50: weights = 2.000, loss = 0.00000000
# epoch 51: weights = 2.000, loss = 0.00000000
# epoch 52: weights = 2.000, loss = 0.00000000
# epoch 53: weights = 2.000, loss = 0.00000000
# epoch 54: weights = 2.000, loss = 0.00000000
# epoch 55: weights = 2.000, loss = 0.00000000
# epoch 56: weights = 2.000, loss = 0.00000000
# epoch 57: weights = 2.000, loss = 0.00000000
# epoch 58: weights = 2.000, loss = 0.00000000
# epoch 59: weights = 2.000, loss = 0.00000000
# epoch 60: weights = 2.000, loss = 0.00000000
# epoch 61: weights = 2.000, loss = 0.00000000
# epoch 62: weights = 2.000, loss = 0.00000000
# epoch 63: weights = 2.000, loss = 0.00000000
# epoch 64: weights = 2.000, loss = 0.00000000
# epoch 65: weights = 2.000, loss = 0.00000000
# epoch 66: weights = 2.000, loss = 0.00000000
# epoch 67: weights = 2.000, loss = 0.00000000
# epoch 68: weights = 2.000, loss = 0.00000000
# epoch 69: weights = 2.000, loss = 0.00000000
# epoch 70: weights = 2.000, loss = 0.00000000
# epoch 71: weights = 2.000, loss = 0.00000000
# epoch 72: weights = 2.000, loss = 0.00000000
# epoch 73: weights = 2.000, loss = 0.00000000
# epoch 74: weights = 2.000, loss = 0.00000000
# epoch 75: weights = 2.000, loss = 0.00000000
# epoch 76: weights = 2.000, loss = 0.00000000
# epoch 77: weights = 2.000, loss = 0.00000000
# epoch 78: weights = 2.000, loss = 0.00000000
# epoch 79: weights = 2.000, loss = 0.00000000
# epoch 80: weights = 2.000, loss = 0.00000000
# epoch 81: weights = 2.000, loss = 0.00000000
# epoch 82: weights = 2.000, loss = 0.00000000
# epoch 83: weights = 2.000, loss = 0.00000000
# epoch 84: weights = 2.000, loss = 0.00000000
# epoch 85: weights = 2.000, loss = 0.00000000
# epoch 86: weights = 2.000, loss = 0.00000000
# epoch 87: weights = 2.000, loss = 0.00000000
# epoch 88: weights = 2.000, loss = 0.00000000
# epoch 89: weights = 2.000, loss = 0.00000000
# epoch 90: weights = 2.000, loss = 0.00000000
# epoch 91: weights = 2.000, loss = 0.00000000
# epoch 92: weights = 2.000, loss = 0.00000000
# epoch 93: weights = 2.000, loss = 0.00000000
# epoch 94: weights = 2.000, loss = 0.00000000
# epoch 95: weights = 2.000, loss = 0.00000000
# epoch 96: weights = 2.000, loss = 0.00000000
# epoch 97: weights = 2.000, loss = 0.00000000
# epoch 98: weights = 2.000, loss = 0.00000000
# epoch 99: weights = 2.000, loss = 0.00000000
# epoch 100: weights = 2.000, loss = 0.00000000
# Prediction after training: f(5) = 10.000
